# %%
#Write a Pandas program to detect missing values of a given DataFrame.
import pandas as pd
import numpy as np

# Given DataFrame
df = pd.DataFrame({
    'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})

# Detect missing values
missing_values = df.isna()

# Display the DataFrame with missing value information
print("DataFrame:")
print(df)

print("\nMissing Values:")
print(missing_values)
# Out:
# DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Missing Values:
#     ord_no  purch_amt  ord_date  customer_id  salesman_id
# 0    False      False     False        False        False
# ...

# %%
#Write a Pandas program to detect missing values of a given DataFrame.
import pandas as pd
import numpy as np

# Given DataFrame
df = pd.DataFrame({
    'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})

# Detect and count missing values
missing_values = df.isna()
missing_count = missing_values.sum()

# Display the DataFrame with missing value information
print("DataFrame:")
print(df)

print("\nMissing Values Count:")
print(missing_count)
# Out:
# DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Missing Values Count:
# ord_no         4
# purch_amt      0
# ord_date       1
# customer_id    0
# salesman_id    3
# dtype: int64

# %%
#Write a Pandas program to drop the rows where at least one element is missing in a given DataFrame.
import pandas as pd
import numpy as np

# Given DataFrame
df = pd.DataFrame({
    'ord_no': [70001, np.nan, 70002, 70004, np.nan, 70005, np.nan, 70010, 70003, 70012, np.nan, 70013],
    'purch_amt': [150.5, 270.65, 65.26, 110.5, 948.5, 2400.6, 5760, 1983.43, 2480.4, 250.45, 75.29, 3045.6],
    'ord_date': ['2012-10-05', '2012-09-10', np.nan, '2012-08-17', '2012-09-10', '2012-07-27', '2012-09-10',
                 '2012-10-10', '2012-10-10', '2012-06-27', '2012-08-17', '2012-04-25'],
    'customer_id': [3002, 3001, 3001, 3003, 3002, 3001, 3001, 3004, 3003, 3002, 3001, 3001],
    'salesman_id': [5002, 5003, 5001, np.nan, 5002, 5001, 5001, np.nan, 5003, 5002, 5003, np.nan]
})

# Drop rows with missing values
df_cleaned = df.dropna()

# Display the original and cleaned DataFrames
print("Original Orders DataFrame:")
print(df)

print("\nDrop the rows where at least one element is missing:")
print(df_cleaned)
# Out:
# Original Orders DataFrame:
#      ord_no  purch_amt    ord_date  customer_id  salesman_id
# 0   70001.0     150.50  2012-10-05         3002       5002.0
# 1       NaN     270.65  2012-09-10         3001       5003.0
# 2   70002.0      65.26         NaN         3001       5001.0
# 3   70004.0     110.50  2012-08-17         3003          NaN
# 4       NaN     948.50  2012-09-10         3002       5002.0
# 5   70005.0    2400.60  2012-07-27         3001       5001.0
# 6       NaN    5760.00  2012-09-10         3001       5001.0
# 7   70010.0    1983.43  2012-10-10         3004          NaN
# 8   70003.0    2480.40  2012-10-10         3003       5003.0
# 9   70012.0     250.45  2012-06-27         3002       5002.0
# 10      NaN      75.29  2012-08-17         3001       5003.0
# 11  70013.0    3045.60  2012-04-25         3001          NaN
#
# Drop the rows where at least one element is missing:
#     ord_no  purch_amt    ord_date  customer_id  salesman_id
# ...

# %%
#Write a Pandas program to split the following data frame into groups based on Class and count the number of students in that particular class.
#Also generate a bar chart based on the result and explain the conclusion.
import pandas as pd
import matplotlib.pyplot as plt

# Given DataFrame
student_data = pd.DataFrame({
    'school_code': ['s001', 's002', 's003', 's001', 's002', 's004'],
    'class': ['V', 'VI', 'VI', 'VI', 'V', 'VI'],
    'name': ['Alberto Franco', 'Gino Mcneill', 'Ryan Parkes', 'Eesha Hinton', 'Gino Mcneill', 'David Parkes'],
    'age': [12, 12, 13, 13, 14, 12],
    'height': [173, 192, 186, 167, 151, 159],
    'weight': [35, 32, 33, 30, 31, 32],
    'address': ['street1', 'street2', 'street3', 'street1', 'street2', 'street4'],
})
#Display the original dataframe
print ("Original Dataframe")
print(student_data)

# Group by 'class' and count the number of students in each class
class_counts = student_data.groupby('class')['name'].count()
#display the class_counts
print("Class Wise No of students Count")
print(class_counts)

# Generate a bar chart
class_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Number of Students in Each Class')
plt.xlabel('Class')
plt.ylabel('Number of Students')
plt.show()
# Out:
# Original Dataframe
#   school_code class            name  age  height  weight  address
# 0        s001     V  Alberto Franco   12     173      35  street1
# 1        s002    VI    Gino Mcneill   12     192      32  street2
# 2        s003    VI     Ryan Parkes   13     186      33  street3
# 3        s001    VI    Eesha Hinton   13     167      30  street1
# 4        s002     V    Gino Mcneill   14     151      31  street2
# 5        s004    VI    David Parkes   12     159      32  street4
# Class Wise No of students Count
# class
# V     2
# VI    4
# Name: name, dtype: int64

# %%
#Conclusion

#From the bar chart, it is evident that Class VI has a higher number of students compared to Class V. 
#Class VI has a taller bar, indicating a larger student population in that class.

# %%
#Write a Pandas program to create a Pivot table and find the total saleamount region wise, manager wise, sales man wise.

import pandas as pd
import numpy as np

# %%
#read the csv file into the Dataframe
df= pd.read_csv("salesdata.csv")
df.head()
# Out:
#     Region  Manager   SalesMan          Item  Units  Unit_price  Sale_amt
# 0     East   Martha  Alexander    Television     95      1198.0  113810.0
# 1  Central  Hermann     Shelli  Home Theater     50       500.0   25000.0
# 2  Central  Hermann       Luis    Television     36      1198.0   43128.0
# 3  Central  Timothy      David    Cell Phone     27       225.0    6075.0
# 4     West  Timothy    Stephen    Television     56      1198.0   67088.0

# %%
#To find the total saleamount region wise, manager wise, sales man wise

pd.pivot_table(df,index=['Region', 'Manager', 'SalesMan'],values=['Sale_amt'],aggfunc=[np.sum],fill_value=0)
# Out:
# C:\Users\anuskaa2003\AppData\Local\Temp\ipykernel_336\2418228815.py:3: FutureWarning: The provided callable <function sum at 0x000002282AB16520> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   pd.pivot_table(df,index=['Region', 'Manager', 'SalesMan'],values=['Sale_amt'],aggfunc=[np.sum],fill_value=0)
#                                 sum
#                            Sale_amt
# Region  Manager SalesMan
# Central Douglas John       124016.0
#         Hermann Luis       206373.0
#                 Shelli      33698.0
#                 Sigal      125037.5
#         Marth   Steven      14000.0
#         Martha  Steven     185690.0
#         Timothy David      140955.0
# East    Douglas Karen       48204.0
#         Martha  Alexander  236703.0
#                 Diana       36100.0
# West    Douglas Michael     66836.0
#         Timothy Stephen     88063.0

# %%
#Write a Pandas program to create a Pivot table and find the item wise unit sold.

# %%
category_sales= df.pivot_table(index='Item',values='Units',aggfunc='sum')

#Display the pivot table
print(category_sales)
# Out:
#               Units
# Item
# Cell Phone      278
# Desk             10
# Home Theater    722
# Television      716
# Video Games     395

# %%
import pandas as pd
from scipy.constants import pi

# Function to calculate the area of a circle
def calculate_circle_area(radius):
    return pi * (radius ** 2)

# Read the CSV file from the given URL
url = "https://raw.githubusercontent.com/AnudipAE/DANLC/master/radius_data.csv"
df = pd.read_csv(url)

# Calculate the area of a circle and add a new column to the DataFrame
df['Area'] = df['Radius'].apply(calculate_circle_area)

# Display the first 5 records
print("First 5 records:")
print(df.head())

# Save the DataFrame with the calculated area to a new CSV file
output_filename = "calculated_area_data.csv"
df.to_csv(output_filename, index=False)

print(f"\nCalculated data saved to {output_filename}")
